# %% [markdown]
# # 5-2. **Sentiment Analysis**

# %%
# !pip install -q nltk
# !pip install -q konlpy

# %% [markdown]
# ## Sentiment analysis ([Vader](https://github.com/cjhutto/vaderSentiment))

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# initialize Vader sentiment analyzer
sia = SentimentIntensityAnalyzer()

text_list = [
                'I really hate you.',
                "I don't like you.",
                'I am a student.',
                'I like you.',
                'I love you very much.'
            ]

for text in text_list:
    print('sentence :', text)
    print('sentiments:', sia.polarity_scores(text))
    print()
# Out:
# sentence : I really hate you.
# sentiments: {'neg': 0.666, 'neu': 0.334, 'pos': 0.0, 'compound': -0.6115}
#
# sentence : I don't like you.
# sentiments: {'neg': 0.513, 'neu': 0.487, 'pos': 0.0, 'compound': -0.2755}
#
# sentence : I am a student.
# sentiments: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# sentence : I like you.
# sentiments: {'neg': 0.0, 'neu': 0.286, 'pos': 0.714, 'compound': 0.3612}
#
# sentence : I love you very much.
# sentiments: {'neg': 0.0, 'neu': 0.417, 'pos': 0.583, 'compound': 0.6369}

# %% [markdown]
# ## Korean sentiment analysis ([eKoNLPy](https://github.com/entelecheia/eKoNLPy))

# %%
# !git clone https://github.com/entelecheia/eKoNLPy.git
# %cd eKoNLPy/
# !pip install .
# %cd ..
# Out:
# fatal: destination path 'eKoNLPy' already exists and is not an empty directory.
# /content/eKoNLPy
# Processing /content/eKoNLPy
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: click<9.0.0,>=8.1.6 in /usr/local/lib/python3.10/dist-packages (from eKoNLPy==2.0.3) (8.1.7)
# Requirement already satisfied: fugashi<2.0.0,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from eKoNLPy==2.0.3) (1.3.0)
# Requirement already satisfied: mecab-ko-dic<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from eKoNLPy==2.0.3) (1.0.0)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from eKoNLPy==2.0.3) (3.8.1)
# Requirement already satisfied: pandas<=2.0.3,>=1.5.3 in /usr/local/lib/python3.10/dist-packages (from eKoNLPy==2.0.3) (1.5.3)
# Requirement already satisfied: scipy<2.0.0,>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from eKoNLPy==2.0.3) (1.11.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->eKoNLPy==2.0.3) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->eKoNLPy==2.0.3) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->eKoNLPy==2.0.3) (4.66.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas<=2.0.3,>=1.5.3->eKoNLPy==2.0.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<=2.0.3,>=1.5.3->eKoNLPy==2.0.3) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas<=2.0.3,>=1.5.3->eKoNLPy==2.0.3) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas<=2.0.3,>=1.5.3->eKoNLPy==2.0.3) (1.16.0)
# Building wheels for collected packages: eKoNLPy
#   Building wheel for eKoNLPy (pyproject.toml) ... done
#   Created wheel for eKoNLPy: filename=ekonlpy-2.0.3-py3-none-any.whl size=10253596 sha256=a05a9bfbd6fb9b714794f86f49d3fcaf01602c51324d9a6eeef9ca52ea506d3c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zwck9e7s/wheels/86/8a/58/97001bb273b6e988301c99b893f814fadb553b44471f34ede5
# Successfully built eKoNLPy
# Installing collected packages: eKoNLPy
#   Attempting uninstall: eKoNLPy
#     Found existing installation: eKoNLPy 2.0.3
#     Uninstalling eKoNLPy-2.0.3:
#       Successfully uninstalled eKoNLPy-2.0.3
# Successfully installed eKoNLPy-2.0.3
# /content

# %%
from ekonlpy.sentiment import KSA

text = [
        '오늘은 날씨가 맑아서 기분이 너무나 좋다.',
        '물가가 너무 올라서 살기가 힘들다.',
        '매일 KOSPI 지수가 하락하고 있고, 환율은 매일 치솟고 있다.'
        ]

# initialize Korean sentiment analyzer
ksa = KSA()

for t in text:
    tokens = ksa.tokenize(t)
    score = ksa.get_score(tokens)
    print(t)
    print(score)
    print()
# Out:
# 오늘은 날씨가 맑아서 기분이 너무나 좋다.
# {'Positive': 1, 'Negative': -6, 'Polarity': -0.7142856122449125, 'Subjectivity': 0.9999998571428775}
#
# 물가가 너무 올라서 살기가 힘들다.
# {'Positive': 0, 'Negative': -4, 'Polarity': -0.9999997500000625, 'Subjectivity': 0.9999997500000625}
#
# 매일 KOSPI 지수가 하락하고 있고, 환율은 매일 치솟고 있다.
# {'Positive': 1, 'Negative': -2, 'Polarity': -0.33333322222225925, 'Subjectivity': 0.9999996666667778}
